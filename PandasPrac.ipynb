# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv') 
df.head(2)
# Out:
#                           Indicator PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/kjam/data-wrangling-pycon/master/data/berlin_weather_oldest.csv') 
df1.head(2)
# Out:
#              STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
#
#    TMIN  WDFG  PGTM  ...  WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
# 1 -9999 -9999
#
# [2 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4656 entries, 0 to 4655
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Indicator                4656 non-null   object
#  1   PUBLISH STATES           4656 non-null   object
#  2   Year                     4656 non-null   int64
#  3   WHO region               4656 non-null   object
#  4   World Bank income group  4656 non-null   object
#  5   Country                  4656 non-null   object
#  6   Sex                      4656 non-null   object
#  7   Display Value            4656 non-null   int64
#  8   Numeric                  4656 non-null   float64
#  9   Low                      0 non-null      float64
#  10  High                     0 non-null      float64
#  11  Comments                 0 non-null      float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 436.6+ KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117208 entries, 0 to 117207
# Data columns (total 21 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   STATION       117208 non-null  object
#  1   STATION_NAME  117208 non-null  object
#  2   DATE          117208 non-null  int64
#  3   PRCP          117208 non-null  int64
#  4   SNWD          117208 non-null  int64
#  5   SNOW          117208 non-null  int64
#  6   TMAX          117208 non-null  int64
#  7   TMIN          117208 non-null  int64
#  8   WDFG          117208 non-null  int64
#  9   PGTM          117208 non-null  int64
#  10  WSFG          117208 non-null  int64
#  11  WT09          117208 non-null  int64
#  12  WT07          117208 non-null  int64
#  13  WT01          117208 non-null  int64
#  14  WT06          117208 non-null  int64
#  15  WT05          117208 non-null  int64
#  16  WT04          117208 non-null  int64
#  17  WT16          117208 non-null  int64
# ...

# %%
# Get the row names as an array
row_names = df.index.to_numpy()

row_names
# Out:
# array([   0,    1,    2, ..., 4653, 4654, 4655], dtype=int64)

# %%
df.columns
# Out:
# Index(['Indicator', 'PUBLISH STATES', 'Year', 'WHO region',
#        'World Bank income group', 'Country', 'Sex', 'Display Value', 'Numeric',
#        'Low', 'High', 'Comments'],
#       dtype='object')

# %%
df = df.rename(columns = {'Indicator':'Indicator Id','Year':'Years'})

# %%
df
# Out:
#                                          Indicator Id PUBLISH STATES  Years  \
# 0                    Life expectancy at birth (years)      Published   1990
# 1                    Life expectancy at birth (years)      Published   2000
# 2                   Life expectancy at age 60 (years)      Published   2012
# 3                   Life expectancy at age 60 (years)      Published   2000
# 4                    Life expectancy at birth (years)      Published   2012
# ...                                               ...            ...    ...
# 4651  Healthy life expectancy (HALE) at birth (years)      Published   2012
# 4652  Healthy life expectancy (HALE) at birth (years)      Published   2012
# 4653  Healthy life expectancy (HALE) at birth (years)      Published   2000
# 4654  Healthy life expectancy (HALE) at birth (years)      Published   2000
# 4655  Healthy life expectancy (HALE) at birth (years)      Published   2012
#
# ...

# %%
sorted(df['Years'])
# Out:
# [1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
# ...

# %%
col = ['Indicator Id', 'WHO region', 'Country','Years']
sdf = df.sort_values(col)
sdf
# Out:
#                                          Indicator Id PUBLISH STATES  Years  \
# 3408  Healthy life expectancy (HALE) at birth (years)      Published   2000
# 3734  Healthy life expectancy (HALE) at birth (years)      Published   2000
# 4114  Healthy life expectancy (HALE) at birth (years)      Published   2000
# 3409  Healthy life expectancy (HALE) at birth (years)      Published   2012
# 3735  Healthy life expectancy (HALE) at birth (years)      Published   2012
# ...                                               ...            ...    ...
# 1915                 Life expectancy at birth (years)      Published   2000
# 3096                 Life expectancy at birth (years)      Published   2000
# 286                  Life expectancy at birth (years)      Published   2012
# 669                  Life expectancy at birth (years)      Published   2012
# 1073                 Life expectancy at birth (years)      Published   2012
#
# ...

# %%
df.iloc[1, 2]
# Out:
# 2000

# %%
clist = list(df.columns)
Clist = clist[5:6] + clist[0:5]+clist[6:]
Clist
# Out:
# ['Country',
#  'Indicator Id',
#  'PUBLISH STATES',
#  'Years',
#  'WHO region',
#  'World Bank income group',
#  'Sex',
#  'Display Value',
#  'Numeric',
#  'Low',
#  'High',
#  'Comments']

# %%
df[Clist]
# Out:
#                    Country                                     Indicator Id  \
# 0                  Andorra                 Life expectancy at birth (years)
# 1                  Andorra                 Life expectancy at birth (years)
# 2                  Andorra                Life expectancy at age 60 (years)
# 3                  Andorra                Life expectancy at age 60 (years)
# 4     United Arab Emirates                 Life expectancy at birth (years)
# ...                    ...                                              ...
# 4651                 Samoa  Healthy life expectancy (HALE) at birth (years)
# 4652                 Yemen  Healthy life expectancy (HALE) at birth (years)
# 4653          South Africa  Healthy life expectancy (HALE) at birth (years)
# 4654                Zambia  Healthy life expectancy (HALE) at birth (years)
# 4655              Zimbabwe  Healthy life expectancy (HALE) at birth (years)
#
# ...

# %%
df.dtypes
# Out:
# Indicator Id                object
# PUBLISH STATES              object
# Years                        int64
# WHO region                  object
# World Bank income group     object
# Country                     object
# Sex                         object
# Display Value                int64
# Numeric                    float64
# Low                        float64
# High                       float64
# Comments                   float64
# dtype: object

# %%
newClist = df['WHO region'].to_numpy()
newClist
# Out:
# array(['Europe', 'Europe', 'Europe', ..., 'Africa', 'Africa', 'Africa'],
#       dtype=object)

# %%
newSet = df.iloc[[11, 24, 37]]
pf = pd.DataFrame(newSet)
pf
# Out:
#                          Indicator Id PUBLISH STATES  Years       WHO region  \
# 11   Life expectancy at birth (years)      Published   2012           Europe
# 24  Life expectancy at age 60 (years)      Published   2012  Western Pacific
# 37  Life expectancy at age 60 (years)      Published   2012           Europe
#
#    World Bank income group            Country     Sex  Display Value  Numeric  \
# 11             High-income            Austria  Female             83     83.0
# 24             High-income  Brunei Darussalam  Female             21     21.0
# 37             High-income             Cyprus  Female             26     26.0
#
#     Low  High  Comments
# 11  NaN   NaN       NaN
# 24  NaN   NaN       NaN
# 37  NaN   NaN       NaN

# %%
# List of rows to exclude
exclude_list = [5, 12, 23, 56]

# Boolean mask to keep rows not in the exclude list
mask = ~df.index.isin(exclude_list)

# Get subset using iloc and the mask
df_subset = df.iloc[mask]

# Print the subset
pf = pd.DataFrame(df_subset)
pf.head(10)
# Out:
#                          Indicator Id PUBLISH STATES  Years  \
# 0    Life expectancy at birth (years)      Published   1990
# 1    Life expectancy at birth (years)      Published   2000
# 2   Life expectancy at age 60 (years)      Published   2012
# 3   Life expectancy at age 60 (years)      Published   2000
# 4    Life expectancy at birth (years)      Published   2012
# 6   Life expectancy at age 60 (years)      Published   1990
# 7   Life expectancy at age 60 (years)      Published   2012
# 8    Life expectancy at birth (years)      Published   2012
# 9    Life expectancy at birth (years)      Published   2000
# 10   Life expectancy at birth (years)      Published   2012
#
#                WHO region World Bank income group               Country  \
# 0                  Europe             High-income               Andorra
# 1                  Europe             High-income               Andorra
# 2                  Europe             High-income               Andorra
# ...
